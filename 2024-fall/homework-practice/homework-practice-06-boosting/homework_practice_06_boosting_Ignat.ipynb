# %% [markdown]
# # Машинное обучение, ФКН ВШЭ
#
# # Практическое задание 6. Бустинговое
#
# ## Общая информация
#
# Дата выдачи: 12.12.2024
#
# Мягкий дедлайн: 22.12.2024 23:59 MSK
#
# Жёсткий дедлайн: 22.12.2024 23:59 MSK
#
# ## Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# ## Формат сдачи
# Задания сдаются через систему anytask. Посылка должна содержать:
# * Ноутбук homework-practice-06-Username.ipynb
#
# Username — ваша фамилия на латинице

# %% [markdown]
# # Примерно на 6 баллов

# %% [markdown]
# ## О задании
#
# В этом задании вам предстоит вручную запрограммировать один из самых мощных алгоритмов машинного обучения — бустинг. Однако с большой силой приходит и большая ответственность, так что заодно научимся, как его правильно готовить

# %%
from warnings import filterwarnings

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.sparse import load_npz
from sklearn.model_selection import train_test_split

sns.set(style='darkgrid')
filterwarnings('ignore')

# %%
X = load_npz('x.npz')
y = np.load('y.npy')

# %% [markdown]
# Разделим на обучающую, валидационную и тестовую выборки (оставьте `random_state=1337` для воспроизводимости).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, test_size=0.5, random_state=1337)

X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((18825, 169), (2354, 169), (2353, 169))

# %% [markdown]
# ---
#
# ## Задание 1. Базовый градиентный бустинг (4 балла)
#
# Первая часть посвящена реализации собственного градиентного бустинга. Обращаем внимание, что пользоваться готовыми реализациями <font color='lightcoral'>**нельзя**</font>, если специально не оговорено. На все <font color='plum'>**вопросы**</font> должен быть <font color='plum'>**ответ**</font>. В заданиях есть референсы для параметров, которые нужно сделать, на случай, если объяснение из ноутбука непонятно, тогда советуем обратиться к соответствующей документации
#
# Вам нужно дописать код в файлике `boosting.py`. Для вас уже подготовлен шаблон класса `Boosting`, вы можете менять его по своему усмотрению.
#
# ### Инструкции для функций:
#
# #### `__init__`
#
# Обязательные параметры:
#  — `base_model_class` — класс базовой модели нашего бустинга
#  — `base_model_params` — словарь с гиперпараметрами для базовой модели
#  — `n_estimators` — какое количество базовых моделей нужно обучить
#  — `learning_rate` — темп обучения, должен быть из полуинтервала $(0, 1]$
#
# #### `fit`
#
# В `fit` приходит выборка, на которой мы обучаем новые базовые модели
#
# Сначала нам нужно сделать какую-то нулевую модель, сделать предсказания (в шаблоне это нулевая модель, соответственно предсказания это просто `np.zeros`). После этого нужно обучить `n_estimators` базовых моделей (как и на что обучаются базовые модели смотрите в лекциях и семинарах). После каждой обученной базовой модели мы должны обновить текущие предсказания, посчитать ошибку на выборке (используем `loss_fn` для этого) и найти новую оптимальную гамму
#
# После всего цикла обучения надо нарисовать график (если `plot=True`).
#
# #### `partial_fit`
#
# В `partial_fit` приходит обучающая выборка, на которую обучается новая базовая модель
#
# #### `predict_proba`
#
# В `predict_proba` приходит любая выборка, нужно предсказать вероятности для неё. Суммируем предсказания базовых моделей на этой выборке (не забываем про гаммы) и накидываем сигмоиду
#
# #### `plot_history`
#
# В `plot_history` приходит любая выборка, для которой последовательно считаются значения функции потерь и/или любой метрики, которую вы хотите посчитать, путем последовательного применения базовых моделей. Можно делать сразу во время обучения, можно делать иначе

# %%
# %load_ext autoreload

# %%
# %autoreload 2

from boosting import Boosting

# %% [markdown]
# ### Проверка кода

# %%
boosting = Boosting(n_estimators=100)

boosting.fit(X_train, y_train, X_valid, y_valid)
boosting.plot_history()

assert len(boosting.models) == boosting.n_estimators
assert len(boosting.gammas) == boosting.n_estimators

assert boosting.predict_proba(X_test).shape == (X_test.shape[0], 2)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.9080
# Test ROC-AUC 0.9041

# %%
boosting = Boosting(n_estimators=100, base_model_params=dict(max_depth=3, min_samples_leaf=5))

boosting.fit(X_train, y_train, X_valid, y_valid)
boosting.plot_history()

assert len(boosting.models) == boosting.n_estimators
assert len(boosting.gammas) == boosting.n_estimators

assert boosting.predict_proba(X_test).shape == (X_test.shape[0], 2)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9441
# Valid ROC-AUC 0.9211
# Test ROC-AUC 0.9210

# %% [markdown]
# ---
#
# ## Задание 2. Имплементация гиперпараметров (2.5 балла + 3.5 бонус)
#
# Бустинг, как метод агрегации, предлагает несколько вариантов регуляризации безотносительно базовой модели. В этом пункте предлагается имплементировать часть из них. При необходимости можете обратиться к реализациям в вашей любимой библиотеке, там могут быть дополнительные пояснения и/или ссылки на оригинальные статьи
#
# <font color='lightcoral'>**Важно!**</font> После добавления каждого параметра проверьте, как это повлияет на качество. Специально крутить параметры не нужно, но важно увидеть, что перформанс модели изменился, в худшую или в лучшую сторону, для этого какие-то параметры нужны, пусть и от балды, <font color='lightcoral'>**дефолтные параметры не подойдут**</font>, они скорее для референса. Лучше всего это видно по графикам обучения <font color='lightcoral'>**на трейне и валидации**</font>, рекомендуется смотрить именно на них
#
# ### 2.1. Борьба с переобучением (0.5 балла)
#
# Как известно, бустинги бывают склонны к переобучению. Чтобы этого не допустить, можно контролировать процесс обучения и проверять критерий останова на валидации. Реализуйте такую процедуру, не забудьте, что всю предобработку, что вы будете делать для трейна, нужно будет повторить на валидации
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | <td colspan=3>`early_stopping_rounds`, `eval_set` |
#
# Добавьте параметры:
# - `early_stopping_rounds: int | None = 0` — число раундов для критерия останова. Если качество ухудшается на протяжении всех раундов подряд, останавливаем обучение
# - `X_val`, `y_val` или `eval_set: Tuple[np.ndarray] | None = None` — валидацонная выборка, на которой будем проверять переобучение

# %%
boosting = Boosting(n_estimators=200, early_stopping_rounds=3)

boosting.fit(X_train, y_train, X_valid, y_valid)
boosting.plot_history()

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9998
# Valid ROC-AUC 0.9050
# Test ROC-AUC 0.8989

# %% [markdown]
# Ничего не изменилось, слишком мало итераций запускаем

# %% [markdown]
# ### Бонус. Бустинг линейных моделей (0.5 балла)
#
# **<font color='plum'>Вопрос:** что произойдет при ансамблировании линейных моделей? Имеет ли это смысл?</font>
#
# <font color='plum'>**Ответ:** </font> ну там смещение большое и маленький разброс, так что все модели после первой будут немного добавлять.
#
# Давайте убедимся. Обучите бустинг, где в качестве базовой модели будет линейная регрессия. Обязательно сохраните историю функции потерь и зафиксируйте время обучения. Можно взять уже готовый из <font color='lightblue'>**XGBoost**</font>, но будьте готовы разобраться с тем, как оттуда достать историю обучения
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `XGBClassifier(booster="gblinear")` | — | — |

# %%
from sklearn.linear_model import Ridge

boosting = Boosting(n_estimators=100, base_model_class=Ridge)

boosting.fit(X_train, y_train, X_valid, y_valid)
boosting.plot_history()

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9564
# Valid ROC-AUC 0.9339
# Test ROC-AUC 0.9268

# %%
from sklearn.linear_model import Ridge

boosting = Boosting(n_estimators=500, base_model_class=Ridge, early_stopping_rounds=2)

boosting.fit(X_train, y_train, X_valid, y_valid)
boosting.plot_history()

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9552
# Valid ROC-AUC 0.9333
# Test ROC-AUC 0.9248

# %% [markdown]
# Теперь возьмите `sklearn.linear_model.SGDClassifier` иобучите на тех же данных. Не забудьте вытащить историю функции потерь

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# Покажите на одном графике изменение функции потерь для бустинга и SGD классификатора. Сравните следующие детали у бустинга и линейной модели:
#
# - время обучения
# - сходимость (как быстро, как стабильно и прочее)
# - графики функции потерь на трейне и на валидации

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# <font color='plum'>**Вопрос:** Какой вывод вы можете сделать?</font>
#
# <font color='plum'>**Ответ:** ...</font>

# %% [markdown]
# ### 2.2. Бутстрап (0.5 балла)
# Как известно, при обучении базовых алгоритмов в беггинге, используется бутстрапированная выборка. Звучит хайпово, почему бы не попробовать сделать то же самое в бустинге?
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `subsample`, — | `subsample`, `bagging`| `subsample`, `bootstrap_type`|
#
# Вам нужно реализовать параметры:
# - `subsample: float | int = 1.0` — доля или число объектов, на которой будет обучаться базовая модель (какую часть составляет бутстрапная выборка от исходной обучающей). Соответствует бутстрапу типа `Bernoulli`. Каждый объект либо входит в подвыборку, либо нет
# - `bagging_temperature: float | int = 1.0` — веса объектов, которые попадают в выборку. Соответствует бутстрапу типа `Bayesian`. Каждый объект имеет определенный вес $t$, на который впоследствии домножается по формуле $w = (-\log(X))^t$, где $X \sim {U[0, 1]}$, после чего попадает в выборку. Таким образом можно сделать симуляцию повторений
# - `bootstrap_type: str | None = 'Bernoulli'` — тип бутстрапа
#
# <font color='plum'>**Вопрос:** как бутстрап может помочь в обучении с точки зрения смещения, разброса и вообще?</font>
#
# <font color='plum'>**Ответ:** ... </font>

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ### Бонус. GOSS (0.5 балла)
#
# Заметим, что во время обучения не все объекты одинаково важны. Один из вариантов это исправить — ввести какие-то веса на объекты, однако можно пойти чуть хитрее. В <font color='lightgreen'>**LightGBM**</font> придумали подход [Gradient-based One-side Sampling](https://www.microsoft.com/en-us/research/wp-content/uploads/2017/11/lightgbm.pdf)
#
# Давайте оценивать важность объектов в отдельный момент обучения нового дерева. Будем считать, какой антиградиент привносит каждый объект. Далее разобъем градиенты на 2 группы. Объекты с большими градиентами берутся все, с маленькими — только часть, по аналогии с бутстрапом, с отрицательными — выкидываются. И не забываем домножить на фактор, чтобы учесть выкинутые объекты. Подробнее в статье
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | — | `bagging='goss'`| `bootstrap_type='MVS'`|
#
# Параметры, которые нужно сделать:
#
# - `goss: bool | None = False` — GOSS бустинг или нет
# - `goss_k: float | int = 0.2` — доля объектов, градиенты которых будем считать большими. Все остальное — маленькими
# - `subsample: float | int = 0.3` — параметры сэмплинга для маленьких градиентов из пункта 2.1

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ### 2.3. Работа с признаками (1 балл)
#
# 1. Помимо выбора случайных объектов, есть идея выбирать случайное подмножество признаков, заложенная в Random Forest. Мотивация это делать точно та же самая, что и в бутстрапировании, за это будет отвечать `rsm`
#
# 2. С другой стороны, вместо того, чтобы выкидывать признаки, можно попробовать проредить их множество значений, применив бинаризацию. В идеале это стоит делать с датасетом до обучения модели, но не обязательно, можно, например, на этапе `fit`, а в `partial_fit` приходит уже квантизованный датасет. Для этого существует множество алгоритмов, мы предлагаем сделать два наиболее простых:
#
# - $\text{Uniform}$. Значения признака $[\min f_i, \max f_i]$ отображаются в `nbins` отрезков одинаковой длины, которые полностью покрывают интервал
# - $\text{Quantile}$. Тот же самый отрезок сортируется и бьется на `nbins` квантилей от 0 до 1
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `colsample_bytree`, `tree_method` | `colsample_bytree`, `max_bin`| `rsm`, `quantize(...)`|
#
# Нужно добавить параметры:
# - `rsm: float | int = 1.0` — доля или число признаков, участвующих в обучении модели. Каждый признак либо входит, либо не входит в пул, на котором обучается базовый алгоритм, по аналогии с бутстрапом Бернулли
# - `quantization_type: str | None = None` — тип квантизации, если она есть
# - `nbins: int = 255` — число бинов для квантизации. Игнорируем, если тип квантизации не указан
#
# <font color='plum'>**Вопрос**: как квантизация поможет в обработке выбросов и нанов?</font>
#
# <font color='plum'>**Ответ**: ... </font>
#
# <font color='plum'>**Вопрос**: можно ли просто заполнить наны каким-то числом? Имеет ли значение, что это за число (-1, -100, -1e32)?</font>
#
# <font color='plum'>**Ответ**: ... </font>

# %% [markdown]
# ### Бонус. Квантизация (1.5 балл)
#
# В текущих имплементациях бустинга используются более сложные методы квантизации. К сожалению, способы выше страдают либо от неравноправности бинов — в каких-то объектов больше, в каких-то меньше, либо от того, что целевая переменная от бинов зависит опосредованно. Предлагается это исправить следующими способами:
#
# 1. $\text{MinEntropy}$. Это [один из методов](https://catboost.ai/docs/en/concepts/quantization), который используется для бинаризации в <font color='palegoldenrod'>**CatBoost**</font>, остальные на него очень похожи. Будем жадно набирать бины так, чтобы энтропия объектов внутри ($\sum_{i \in \text{bin}} x_i\log(x_i)$) была как можно меньше. Сделать такое разбиение руками непросто, но вам эта задача должна что-то напоминать
#
# 2. $\text{PiecewiseEncoding}$. Это относительно свежий метод для [табличных трансформеров](https://arxiv.org/pdf/2203.05556). Суть заключается в том, что бины для квантизации будем брать не с потолка, а именно те, что нужны для разбиения таргета. (В статье делается кодирование в вектор длины $T$, где $T$ число бинов, в нашем случае это излишне, бинов можно оставить столько же, но взять лмшь закодированную по формуле часть)
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | — | — | `feature_border_type="Piecewise"` |
#
# Нужно добавить опцию:
#
# - `'MinEntropy'` для `quantization_type` — какую квантизацию используем
#
# Реализуйте оба способа подсчета (или один, но тогда балл неполный) и сравните, удалось ли улучшить качество?

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ### 2.4. Важность признаков (0.5 балла)
#
# Поскольку наша базовая модель — это дерево из `sklearn`, мы можем вычислить важность признака отдельно для каждого дерева и усреднить (воспользуйтесь `feature_importances_` у `DecisionTreeRegressor`), после этого нормировать значения, чтобы они суммировались в единицу (обратите внимание, что они должны быть неотрицательными — иначе вы что-то сделали не так). Разумеется, способ не единственный, если хочется, посмотрите в документации
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `model.get_score()` | `lightgbm.importance()` | `model.get_feature_importance()` |
#
# Допишите к бустингу:
# - `feature_importances_` — атрибут, который возвращает важность признаков, согласно методу выше

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# Покажите, какие признаки оказались самыми важными

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ### Бонус. DART (1.5 балла)
#
# Ранее мы обсуждали, что каждый базовый алгоритм пытается исправить ошибки всего предыдущего ансамбля. Из-за этого возникает неравноправие — каждая новая модель вносит все меньший и меньший вклад. Уверенные обучатели нейросетей знают, что это может привести к переобучению. Но выход есть, и выход этот [DART](https://arxiv.org/pdf/1505.01866)!
#
# В DL есть такой вид регуляризации, как dropout, когда некоторые узлы нейросети со случайным шансом отключаются. Можно попробовать обобщить этот подход на случай бустингов и случайно выкидывать деревья из композиции во время обучения
#
# 1. Выбираем, какие деревья убрать. При подсчете антиградиента берем не весь ансамбль, а только ту часть, что осталась
# 2. Домножаем выходы дерева на $1/k$, где $k$ — число удаленных деревьев, чтобы учесть тот факт, что ансамбль был не весь. Тогда вклад отдельного дерева будет не настолько большим
# 3. Домножаем выходы выкинутых деревьев на $k/(k+1)$, чтобы масштабы выходов примерно совпадали
#
# | <font color='lightblue'>XGBoost</font> | <font color='lightgreen'>LightGBM</font> | <font color='palegoldenrod'>CatBoost</font> |
# | --- | --- | --- |
# | `XGBClassifier(booster="dart")` | `LGBMClassifier(boosting_type="dart")` | — |
#
# Параметры, которые нужно добавить:
#
# - `dart: bool | None = False` — DART бустинг или нет
# - `dropout_rate: int | float = 0.05` — доля деревьев, которую выкидываем во время обучения DART

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ------
#
# ## Задание 3. Оптимизация (3.5 балла + 0.5 бонус)
#
# Теперь давайте подумаем, как же правильно применять бустинги. Нас интересует: какие бустинги вообще бывают, как их правильно тюнить, и как интерпретировать
#
# Оптимизация моделей с большим числом гиперпараметров это сложное дело. Нетрудно догадаться, что в случае, когда параметров $m$, сложность перебора в самом худшем случае будет порядка $n^m$. У бустингов, хотя на самом деле не только, эта проблема стоит особенно остро. Подумаем, как это делать умнее
#
# ### 3.1. Знакомство с optuna (1 балл)
#
# Для эффективного подбора гиперпараметров существует несколько решений, основанных на байесовской оптимизации. В этом задании предлагается познакомиться с библиотекой [optuna](https://optuna.org/), которая делает перебор гиперпараметров легким и приятным, а также сохраняет всю историю экспериментов в одно место за вас
#
# Подберите на валидации оптимальные значения следующих гиперпараметров для вашей реализации бустинга:
# - `max_depth`
# - `n_estimators`
# - `learning_rate`
# - любые другие параметры, которые вам понравились
#
# Заметим, что оптуна это крайне гибкая библиотека, в которой можно реализовать абсолютно любую логику, которую пожелаете. За вас там есть лишь выбор модели. Чтобы не плодить несколько `objective`, можно слегка менять тело функции, например, добавить опциональные параметры, но шаблоном пользоваться не обязательно, как обычно
#
# Подберите диапазон параметров самостоятельно, не забывайте фиксировать сид (нет, его не нужно перебирать). Сохраните и покажите оптимальный набор параметров. Сравните графики функций потерь для оптимального и дефолтного бустингов. Покажите, какие параметры дали наибольший прирост (для этого придется почитать документацию оптуны)

# %%
import optuna
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score

np.random.seed(42)

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 300)
    learning_rate = trial.suggest_float('learning_rate', 0.05, 0.95)

    base_model_params = dict(
        max_depth = trial.suggest_int('max_depth', 1, 8),
    )
    
    boosting = Boosting(n_estimators=n_estimators, learning_rate=learning_rate, \
                        base_model_params=base_model_params)

    boosting.fit(X_train, y_train)

    return boosting.score(X_valid, y_valid)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_jobs=-1, show_progress_bar=True, n_trials=50)
# Out:
# [I 2024-12-22 19:38:39,109] A new study created in memory with name: no-name-84d05c99-8e87-4764-a686-7b6813af1123
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2024-12-22 19:38:48,685] Trial 5 finished with value: 0.906126754324 and parameters: {'n_estimators': 106, 'learning_rate': 0.7816255981664676, 'max_depth': 1}. Best is trial 5 with value: 0.906126754324.
# [I 2024-12-22 19:38:51,823] Trial 9 finished with value: 0.9180485348007277 and parameters: {'n_estimators': 137, 'learning_rate': 0.35723123993509154, 'max_depth': 2}. Best is trial 9 with value: 0.9180485348007277.
# [I 2024-12-22 19:38:52,382] Trial 8 finished with value: 0.9309756368167186 and parameters: {'n_estimators': 127, 'learning_rate': 0.0801510178156866, 'max_depth': 5}. Best is trial 8 with value: 0.9309756368167186.
# [I 2024-12-22 19:38:53,171] Trial 2 finished with value: 0.907771027742724 and parameters: {'n_estimators': 149, 'learning_rate': 0.06434411280464578, 'max_depth': 2}. Best is trial 8 with value: 0.9309756368167186.
# [I 2024-12-22 19:38:53,350] Trial 6 finished with value: 0.919985744309098 and parameters: {'n_estimators': 152, 'learning_rate': 0.47221566133071186, 'max_depth': 2}. Best is trial 8 with value: 0.9309756368167186.
# [I 2024-12-22 19:38:54,463] Trial 10 finished with value: 0.9377830085893332 and parameters: {'n_estimators': 131, 'learning_rate': 0.44569498081024445, 'max_depth': 8}. Best is trial 10 with value: 0.9377830085893332.
# [I 2024-12-22 19:38:54,891] Trial 1 finished with value: 0.9334137111650156 and parameters: {'n_estimators': 158, 'learning_rate': 0.6812951801918086, 'max_depth': 4}. Best is trial 10 with value: 0.9377830085893332.
# [I 2024-12-22 19:38:55,677] Trial 0 finished with value: 0.9377043867778068 and parameters: {'n_estimators': 140, 'learning_rate': 0.1562048028481364, 'max_depth': 8}. Best is trial 10 with value: 0.9377830085893332.
# [I 2024-12-22 19:38:57,731] Trial 3 finished with value: 0.93612676230591 and parameters: {'n_estimators': 173, 'learning_rate': 0.47581532105305235, 'max_depth': 6}. Best is trial 10 with value: 0.9377830085893332.
# [I 2024-12-22 19:38:59,279] Trial 4 finished with value: 0.9338275731881265 and parameters: {'n_estimators': 195, 'learning_rate': 0.8139319531973236, 'max_depth': 5}. Best is trial 10 with value: 0.9377830085893332.
# [I 2024-12-22 19:39:04,343] Trial 7 finished with value: 0.9056901438579602 and parameters: {'n_estimators': 278, 'learning_rate': 0.2668149066225816, 'max_depth': 1}. Best is trial 10 with value: 0.9377830085893332.
# [I 2024-12-22 19:39:05,460] Trial 15 finished with value: 0.918945701462206 and parameters: {'n_estimators': 132, 'learning_rate': 0.4269457183300484, 'max_depth': 2}. Best is trial 10 with value: 0.9377830085893332.
# [I 2024-12-22 19:39:05,970] Trial 11 finished with value: 0.9384271487101633 and parameters: {'n_estimators': 232, 'learning_rate': 0.6965829771659331, 'max_depth': 8}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:08,177] Trial 13 finished with value: 0.9332448937727533 and parameters: {'n_estimators': 163, 'learning_rate': 0.9038270362808661, 'max_depth': 4}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:08,488] Trial 14 finished with value: 0.9047319155865146 and parameters: {'n_estimators': 177, 'learning_rate': 0.30180763128060023, 'max_depth': 1}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:10,333] Trial 16 finished with value: 0.920176911048799 and parameters: {'n_estimators': 181, 'learning_rate': 0.594938677584403, 'max_depth': 2}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:10,639] Trial 19 finished with value: 0.9080296416202318 and parameters: {'n_estimators': 164, 'learning_rate': 0.8084909776699744, 'max_depth': 1}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:15,880] Trial 18 finished with value: 0.9277705009366771 and parameters: {'n_estimators': 205, 'learning_rate': 0.06102561223459141, 'max_depth': 4}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:16,386] Trial 12 finished with value: 0.9364049318624269 and parameters: {'n_estimators': 247, 'learning_rate': 0.6917314248837158, 'max_depth': 7}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:20,229] Trial 17 finished with value: 0.9220825920134608 and parameters: {'n_estimators': 270, 'learning_rate': 0.5164196481907561, 'max_depth': 2}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:23,355] Trial 20 finished with value: 0.9230416184758863 and parameters: {'n_estimators': 267, 'learning_rate': 0.7474320396094674, 'max_depth': 2}. Best is trial 11 with value: 0.9384271487101633.
# [I 2024-12-22 19:39:30,232] Trial 21 finished with value: 0.9387005291208007 and parameters: {'n_estimators': 260, 'learning_rate': 0.28967922722120865, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:32,186] Trial 22 finished with value: 0.9384431125297625 and parameters: {'n_estimators': 232, 'learning_rate': 0.20518828211649023, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:34,314] Trial 23 finished with value: 0.9386258982641742 and parameters: {'n_estimators': 241, 'learning_rate': 0.21916558605999437, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:34,877] Trial 24 finished with value: 0.9375339730035847 and parameters: {'n_estimators': 243, 'learning_rate': 0.6431619662800383, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:37,518] Trial 25 finished with value: 0.9373815185264116 and parameters: {'n_estimators': 247, 'learning_rate': 0.6161893703988585, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:37,677] Trial 26 finished with value: 0.9378855761302585 and parameters: {'n_estimators': 246, 'learning_rate': 0.6126401313555883, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:38,039] Trial 27 finished with value: 0.9371245010308638 and parameters: {'n_estimators': 233, 'learning_rate': 0.5966242000472053, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:39,307] Trial 28 finished with value: 0.9381306207611071 and parameters: {'n_estimators': 241, 'learning_rate': 0.584953952709098, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:42,843] Trial 29 finished with value: 0.9371233037443938 and parameters: {'n_estimators': 226, 'learning_rate': 0.5974186470016136, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:44,023] Trial 30 finished with value: 0.9383086173496389 and parameters: {'n_estimators': 233, 'learning_rate': 0.6122963022736752, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:47,356] Trial 31 finished with value: 0.9381577592544259 and parameters: {'n_estimators': 228, 'learning_rate': 0.5722463009837745, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:51,615] Trial 32 finished with value: 0.9383620961452963 and parameters: {'n_estimators': 235, 'learning_rate': 0.1782424660615584, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:58,360] Trial 33 finished with value: 0.9386538349484729 and parameters: {'n_estimators': 236, 'learning_rate': 0.20255830995259982, 'max_depth': 8}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:39:58,852] Trial 34 finished with value: 0.9363941562841975 and parameters: {'n_estimators': 233, 'learning_rate': 0.1994431996160393, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:00,664] Trial 35 finished with value: 0.9367477548883212 and parameters: {'n_estimators': 229, 'learning_rate': 0.22471888386670968, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:08,715] Trial 36 finished with value: 0.9367637187079204 and parameters: {'n_estimators': 298, 'learning_rate': 0.19303477591164747, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:11,040] Trial 37 finished with value: 0.9368906310737344 and parameters: {'n_estimators': 296, 'learning_rate': 0.1754846111863916, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:11,288] Trial 39 finished with value: 0.9370877842457853 and parameters: {'n_estimators': 294, 'learning_rate': 0.21090168741263624, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:11,675] Trial 38 finished with value: 0.9369317379092026 and parameters: {'n_estimators': 300, 'learning_rate': 0.1896025059294969, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:12,664] Trial 40 finished with value: 0.9368239821269075 and parameters: {'n_estimators': 297, 'learning_rate': 0.2195502044683434, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:14,525] Trial 44 finished with value: 0.9367756915726198 and parameters: {'n_estimators': 211, 'learning_rate': 0.22130787310257138, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:14,985] Trial 41 finished with value: 0.937096564346565 and parameters: {'n_estimators': 294, 'learning_rate': 0.20404688532945947, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:15,514] Trial 42 finished with value: 0.9368762636360951 and parameters: {'n_estimators': 293, 'learning_rate': 0.19479976016524153, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:17,060] Trial 43 finished with value: 0.9368682817262955 and parameters: {'n_estimators': 295, 'learning_rate': 0.17955654433552354, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:18,006] Trial 47 finished with value: 0.9348125408574006 and parameters: {'n_estimators': 212, 'learning_rate': 0.1130188520237054, 'max_depth': 6}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:20,852] Trial 48 finished with value: 0.9347251389450949 and parameters: {'n_estimators': 211, 'learning_rate': 0.12933818975874872, 'max_depth': 6}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:21,178] Trial 46 finished with value: 0.9364240884459462 and parameters: {'n_estimators': 289, 'learning_rate': 0.11904621440468013, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:21,180] Trial 45 finished with value: 0.9367002625250134 and parameters: {'n_estimators': 297, 'learning_rate': 0.18970959670146811, 'max_depth': 7}. Best is trial 21 with value: 0.9387005291208007.
# [I 2024-12-22 19:40:21,669] Trial 49 finished with value: 0.9345571197438126 and parameters: {'n_estimators': 210, 'learning_rate': 0.11981156811988249, 'max_depth': 6}. Best is trial 21 with value: 0.9387005291208007.

# %%
optuna.visualization.plot_param_importances(study)
# Out:
# <div>                            <div id="c4d1243e-aa3f-4144-8d81-d8821dd21e44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c4d1243e-aa3f-4144-8d81-d8821dd21e44")) {                    Plotly.newPlot(                        "c4d1243e-aa3f-4144-8d81-d8821dd21e44",                        [{"cliponaxis":false,"hovertemplate":["n_estimators (IntDistribution): 0.0073328058414286945\u003cextra\u003e\u003c\u002fextra\u003e","learning_rate (FloatDistribution): 0.021249788984471194\u003cextra\u003e\u003c\u002fextra\u003e","max_depth (IntDistribution): 0.9714174051741\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value","orientation":"h","text":["\u003c0.01","0.02","0.97"],"textposition":"outside","x":[0.0073328058414286945,0.021249788984471194,0.9714174051741],"y":["n_estimators","learning_rate","max_depth"],"type":"bar"}],                        {"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Hyperparameter Importance"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0 ...

# %%
study.best_params
# Out:
# {'n_estimators': 260, 'learning_rate': 0.28967922722120865, 'max_depth': 8}

# %%
boosting = Boosting(n_estimators=260, learning_rate=0.28967922722120865, \
                        base_model_params=dict(max_depth=8))

boosting.fit(X_train, y_train, X_valid, y_valid, True)

print(f'Train ROC-AUC {boosting.score(X_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(X_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(X_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9794
# Valid ROC-AUC 0.9386
# Test ROC-AUC 0.9311

# %% [markdown]
# ### 3.2. Глубокая оптимизация (1 балл)
#
# Помимо эффективного перебора гиперпараметров, `optuna` предлагает более тонкий контроль над самой процедурой обучения. Улучшите процедуру оптимизации следующим образом:
#
# 1. Посмотрите, как в `optuna` устроена запись в хранилища, и добавьте это в пайплайн оптимизации. Без указания БД все запуски оптуны сотрутся, как только закончится сессия. Более того, так можно распараллелить процесс оптимизации на несколько машин
# 2. Посмотрите, как можно контролировать процесс обучения бустинга при помощи прунера. У библиотечных имплементаций есть уже готовые, их можно использовать пунктом ниже. Для кастомной модели возьмите что-то из `optuna.pruners`. Идея прунера — не обучать бустинг до конца, если по истории видно, что другие бустинги на этом этапе статистически лучше.
# 3. Добавьте сохранение истории функции потерь и времени обучения в качестве `user_attribute` сразу в `study`. Мы не хотим оптимизировать их напрямую, но они нам понадобится для сравнения моделей в дальнейшем
#
# Добавьте хранилище и юзер атрибуты и посмотрите, ускорилась ли оптимизация с добавлением прунера

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# ### 3.3. Готовые реализации (1 балл)
#
# Библиотек для бустингов существует много, но активно используются лишь три. Ваша задача — попробовать их в деле, посмотреть на их уникальные фишки и понять, что вам нравится больше всего
#
# Возьмите любую из популярных библиотек: <font color='lightblue'>`xgboost`</font>, <font color='lightgreen'>`lightgbm`</font>, <font color='palegoldenrod'>`catboost`</font>.
# Ваша задача — взять одну из них, подобрать те же оптимальные параметры, что и выше, плюс что-то, что вам понравилось в них больше всего (может быть абсолютно любая фишка из пунктов выше или что-то, что вы найдете сами, не обязательно эксклюзивное), и сравнить две оптимизированные модели по
# - динамике функции потерь (на обучающей и на валидационной выборке)
# - времени обучения

# %%
# *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚

# %% [markdown]
# <font color='plum'>**Вопрос:** Какая архитектура вам нравится больше всего и почему?</font>
#
# <font color='plum'>**Ответ**: ... </font>

# %% [markdown]
# ### Бонус. Random Forest (0.5 балла)
#
# Если очень захотеть, оптуна может оптимизировать все, что угодно, даже нейросети. Давайте противопоставим бустингу его злейшего врага — алгоритм Random Forest.
#
# Возьмите реализацию случайного леса из <font color='lightgreen'>`lightgbm`</font>. Посмотрите, какие там есть гиперпараметры, переберите что-либо из них вместе с `max_depth` и `n_estimators`.
#
# Сравните его качество и динамику функции потерь (на обучающей и на валидационной выборке) с таковыми у бустинга и сделайте вывод, а нужен ли Random Forest?

# %%
import optuna
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score

def objective(trial):
    params = {
        'boosting_type': 'rf',
        'metric': 'binary_logloss',
        'subsample': 0,
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 2),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.8, 1.0),
        'max_depth': trial.suggest_int('max_depth', 8, 16),
        'num_leaves': trial.suggest_int('num_leaves', 31, 63),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'n_estimators': trial.suggest_int('n_estimators', 100, 300),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 50),
    }

    rf_model = LGBMClassifier(**params, verbose=0)

    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict_proba(X_valid)[:, 1]
        
    return roc_auc_score(y_valid, y_pred)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_jobs=-1, show_progress_bar=True, n_trials=50)
# Out:
# [I 2024-12-22 23:11:56,407] A new study created in memory with name: no-name-322defc5-2a79-455b-beec-162f9b775e27
#   0%|          | 0/50 [00:00<?, ?it/s]
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8884277130014453, subsample=0 will be ignored. Current value: bagging_fraction=0.8884277130014453
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8624276491968806, subsample=0 will be ignored. Current value: bagging_fraction=0.8624276491968806
# [LightGBM] [Warning] bagging_fraction is set=0.8130579257173687, subsample=0 will be ignored. Current value: bagging_fraction=0.8130579257173687
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8511906450739003, subsample=0 will be ignored. Current value: bagging_fraction=0.8511906450739003
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8668020750621511, subsample=0 will be ignored. Current value: bagging_fraction=0.8668020750621511
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8214097230812683, subsample=0 will be ignored. Current value: bagging_fraction=0.8214097230812683
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8491895561262849, subsample=0 will be ignored. Current value: bagging_fraction=0.8491895561262849
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8059795990761721, subsample=0 will be ignored. Current value: bagging_fraction=0.8059795990761721
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8798605116679007, subsample=0 will be ignored. Current value: bagging_fraction=0.8798605116679007
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9245101905626725, subsample=0 will be ignored. Current value: bagging_fraction=0.9245101905626725
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9537834600501308, subsample=0 will be ignored. Current value: bagging_fraction=0.9537834600501308
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9530845803424767, subsample=0 will be ignored. Current value: bagging_fraction=0.9530845803424767
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8130579257173687, subsample=0 will be ignored. Current value: bagging_fraction=0.8130579257173687
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8624276491968806, subsample=0 will be ignored. Current value: bagging_fraction=0.8624276491968806
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8884277130014453, subsample=0 will be ignored. Current value: bagging_fraction=0.8884277130014453
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8511906450739003, subsample=0 will be ignored. Current value: bagging_fraction=0.8511906450739003
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8668020750621511, subsample=0 will be ignored. Current value: bagging_fraction=0.8668020750621511
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8214097230812683, subsample=0 will be ignored. Current value: bagging_fraction=0.8214097230812683
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8491895561262849, subsample=0 will be ignored. Current value: bagging_fraction=0.8491895561262849
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8059795990761721, subsample=0 will be ignored. Current value: bagging_fraction=0.8059795990761721
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9245101905626725, subsample=0 will be ignored. Current value: bagging_fraction=0.9245101905626725
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8798605116679007, subsample=0 will be ignored. Current value: bagging_fraction=0.8798605116679007
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9537834600501308, subsample=0 will be ignored. Current value: bagging_fraction=0.9537834600501308
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9530845803424767, subsample=0 will be ignored. Current value: bagging_fraction=0.9530845803424767
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8798605116679007, subsample=0 will be ignored. Current value: bagging_fraction=0.8798605116679007
# [I 2024-12-22 23:12:20,381] Trial 11 finished with value: 0.9267791477395629 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.8798605116679007, 'max_depth': 10, 'num_leaves': 33, 'learning_rate': 0.06374996410602442, 'n_estimators': 139, 'min_child_samples': 23}. Best is trial 11 with value: 0.9267791477395629.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9585334962095009, subsample=0 will be ignored. Current value: bagging_fraction=0.9585334962095009
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9585334962095009, subsample=0 will be ignored. Current value: bagging_fraction=0.9585334962095009
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9537834600501308, subsample=0 will be ignored. Current value: bagging_fraction=0.9537834600501308
# [I 2024-12-22 23:12:27,453] Trial 10 finished with value: 0.9247864639580853 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9537834600501308, 'max_depth': 9, 'num_leaves': 32, 'learning_rate': 0.0603346886014375, 'n_estimators': 191, 'min_child_samples': 49}. Best is trial 11 with value: 0.9267791477395629.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8747595481944671, subsample=0 will be ignored. Current value: bagging_fraction=0.8747595481944671
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8747595481944671, subsample=0 will be ignored. Current value: bagging_fraction=0.8747595481944671
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8491895561262849, subsample=0 will be ignored. Current value: bagging_fraction=0.8491895561262849
# [I 2024-12-22 23:12:31,438] Trial 8 finished with value: 0.9282426309013252 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8491895561262849, 'max_depth': 12, 'num_leaves': 36, 'learning_rate': 0.02672041792961915, 'n_estimators': 188, 'min_child_samples': 22}. Best is trial 8 with value: 0.9282426309013252.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9280375275355903, subsample=0 will be ignored. Current value: bagging_fraction=0.9280375275355903
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9280375275355903, subsample=0 will be ignored. Current value: bagging_fraction=0.9280375275355903
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8214097230812683, subsample=0 will be ignored. Current value: bagging_fraction=0.8214097230812683
# [I 2024-12-22 23:12:33,389] Trial 5 finished with value: 0.9273358859480874 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.8214097230812683, 'max_depth': 8, 'num_leaves': 31, 'learning_rate': 0.07223850494108125, 'n_estimators': 238, 'min_child_samples': 48}. Best is trial 8 with value: 0.9282426309013252.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8326240234750883, subsample=0 will be ignored. Current value: bagging_fraction=0.8326240234750883
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8326240234750883, subsample=0 will be ignored. Current value: bagging_fraction=0.8326240234750883
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8884277130014453, subsample=0 will be ignored. Current value: bagging_fraction=0.8884277130014453
# [I 2024-12-22 23:12:33,420] Trial 1 finished with value: 0.9275478056532674 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8884277130014453, 'max_depth': 11, 'num_leaves': 36, 'learning_rate': 0.04188190334777495, 'n_estimators': 199, 'min_child_samples': 41}. Best is trial 8 with value: 0.9282426309013252.
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8677464790188584, subsample=0 will be ignored. Current value: bagging_fraction=0.8677464790188584
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8677464790188584, subsample=0 will be ignored. Current value: bagging_fraction=0.8677464790188584
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9530845803424767, subsample=0 will be ignored. Current value: bagging_fraction=0.9530845803424767
# [I 2024-12-22 23:12:36,075] Trial 6 finished with value: 0.9269192302565465 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.9530845803424767, 'max_depth': 13, 'num_leaves': 39, 'learning_rate': 0.04645227162927599, 'n_estimators': 195, 'min_child_samples': 19}. Best is trial 8 with value: 0.9282426309013252.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9078221078645838, subsample=0 will be ignored. Current value: bagging_fraction=0.9078221078645838
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9078221078645838, subsample=0 will be ignored. Current value: bagging_fraction=0.9078221078645838
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8668020750621511, subsample=0 will be ignored. Current value: bagging_fraction=0.8668020750621511
# [I 2024-12-22 23:12:38,903] Trial 3 finished with value: 0.9288444669002174 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8668020750621511, 'max_depth': 11, 'num_leaves': 44, 'learning_rate': 0.013380302696187537, 'n_estimators': 187, 'min_child_samples': 34}. Best is trial 3 with value: 0.9288444669002174.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.979688529929908, subsample=0 will be ignored. Current value: bagging_fraction=0.979688529929908
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.979688529929908, subsample=0 will be ignored. Current value: bagging_fraction=0.979688529929908
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8511906450739003, subsample=0 will be ignored. Current value: bagging_fraction=0.8511906450739003
# [I 2024-12-22 23:12:43,973] Trial 4 finished with value: 0.9290136833879695 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8511906450739003, 'max_depth': 13, 'num_leaves': 44, 'learning_rate': 0.0162024359548438, 'n_estimators': 211, 'min_child_samples': 41}. Best is trial 4 with value: 0.9290136833879695.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9081859220598623, subsample=0 will be ignored. Current value: bagging_fraction=0.9081859220598623
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9081859220598623, subsample=0 will be ignored. Current value: bagging_fraction=0.9081859220598623
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8059795990761721, subsample=0 will be ignored. Current value: bagging_fraction=0.8059795990761721
# [I 2024-12-22 23:12:50,722] Trial 9 finished with value: 0.9298461965800711 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.8059795990761721, 'max_depth': 11, 'num_leaves': 51, 'learning_rate': 0.05992303398761754, 'n_estimators': 217, 'min_child_samples': 50}. Best is trial 9 with value: 0.9298461965800711.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9475403962527624, subsample=0 will be ignored. Current value: bagging_fraction=0.9475403962527624
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9475403962527624, subsample=0 will be ignored. Current value: bagging_fraction=0.9475403962527624
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8624276491968806, subsample=0 will be ignored. Current value: bagging_fraction=0.8624276491968806
# [I 2024-12-22 23:12:55,622] Trial 0 finished with value: 0.9319993167485211 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8624276491968806, 'max_depth': 15, 'num_leaves': 61, 'learning_rate': 0.01021704748150668, 'n_estimators': 190, 'min_child_samples': 13}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9230248190389526, subsample=0 will be ignored. Current value: bagging_fraction=0.9230248190389526
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9230248190389526, subsample=0 will be ignored. Current value: bagging_fraction=0.9230248190389526
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8130579257173687, subsample=0 will be ignored. Current value: bagging_fraction=0.8130579257173687
# [I 2024-12-22 23:12:59,613] Trial 2 finished with value: 0.9317730296057016 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8130579257173687, 'max_depth': 12, 'num_leaves': 54, 'learning_rate': 0.013745815297037776, 'n_estimators': 228, 'min_child_samples': 10}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8005906092418401, subsample=0 will be ignored. Current value: bagging_fraction=0.8005906092418401
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8005906092418401, subsample=0 will be ignored. Current value: bagging_fraction=0.8005906092418401
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9280375275355903, subsample=0 will be ignored. Current value: bagging_fraction=0.9280375275355903
# [I 2024-12-22 23:13:00,952] Trial 14 finished with value: 0.9247836702896557 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.9280375275355903, 'max_depth': 12, 'num_leaves': 31, 'learning_rate': 0.05703238949819699, 'n_estimators': 183, 'min_child_samples': 16}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8253692627628477, subsample=0 will be ignored. Current value: bagging_fraction=0.8253692627628477
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8253692627628477, subsample=0 will be ignored. Current value: bagging_fraction=0.8253692627628477
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9245101905626725, subsample=0 will be ignored. Current value: bagging_fraction=0.9245101905626725
# [I 2024-12-22 23:13:02,748] Trial 7 finished with value: 0.9290527947459878 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.9245101905626725, 'max_depth': 11, 'num_leaves': 53, 'learning_rate': 0.09798052848631797, 'n_estimators': 247, 'min_child_samples': 35}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9977736307230748, subsample=0 will be ignored. Current value: bagging_fraction=0.9977736307230748
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9977736307230748, subsample=0 will be ignored. Current value: bagging_fraction=0.9977736307230748
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9078221078645838, subsample=0 will be ignored. Current value: bagging_fraction=0.9078221078645838
# [I 2024-12-22 23:13:07,197] Trial 17 finished with value: 0.9309133779202815 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9078221078645838, 'max_depth': 10, 'num_leaves': 56, 'learning_rate': 0.01714173235651835, 'n_estimators': 110, 'min_child_samples': 12}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8293397998534991, subsample=0 will be ignored. Current value: bagging_fraction=0.8293397998534991
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8293397998534991, subsample=0 will be ignored. Current value: bagging_fraction=0.8293397998534991
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9475403962527624, subsample=0 will be ignored. Current value: bagging_fraction=0.9475403962527624
# [I 2024-12-22 23:13:11,112] Trial 20 finished with value: 0.9256501065984053 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9475403962527624, 'max_depth': 11, 'num_leaves': 35, 'learning_rate': 0.04649358120620593, 'n_estimators': 109, 'min_child_samples': 10}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.999325472913606, subsample=0 will be ignored. Current value: bagging_fraction=0.999325472913606
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.999325472913606, subsample=0 will be ignored. Current value: bagging_fraction=0.999325472913606
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8747595481944671, subsample=0 will be ignored. Current value: bagging_fraction=0.8747595481944671
# [I 2024-12-22 23:13:15,367] Trial 13 finished with value: 0.9303761953907664 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8747595481944671, 'max_depth': 8, 'num_leaves': 50, 'learning_rate': 0.011252613478409142, 'n_estimators': 194, 'min_child_samples': 15}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9880057462660123, subsample=0 will be ignored. Current value: bagging_fraction=0.9880057462660123
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9880057462660123, subsample=0 will be ignored. Current value: bagging_fraction=0.9880057462660123
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.9585334962095009, subsample=0 will be ignored. Current value: bagging_fraction=0.9585334962095009
# [I 2024-12-22 23:13:17,585] Trial 12 finished with value: 0.9273853737888451 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.9585334962095009, 'max_depth': 14, 'num_leaves': 45, 'learning_rate': 0.04239628510864748, 'n_estimators': 248, 'min_child_samples': 29}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8291261289778744, subsample=0 will be ignored. Current value: bagging_fraction=0.8291261289778744
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8291261289778744, subsample=0 will be ignored. Current value: bagging_fraction=0.8291261289778744
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8326240234750883, subsample=0 will be ignored. Current value: bagging_fraction=0.8326240234750883
# [I 2024-12-22 23:13:18,186] Trial 15 finished with value: 0.9288783900168659 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.8326240234750883, 'max_depth': 16, 'num_leaves': 40, 'learning_rate': 0.06676062506343, 'n_estimators': 185, 'min_child_samples': 40}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8080426111186784, subsample=0 will be ignored. Current value: bagging_fraction=0.8080426111186784
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8080426111186784, subsample=0 will be ignored. Current value: bagging_fraction=0.8080426111186784
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.8677464790188584, subsample=0 will be ignored. Current value: bagging_fraction=0.8677464790188584
# [I 2024-12-22 23:13:24,220] Trial 16 finished with value: 0.9276571578175223 and parameters: {'bagging_freq': 1, 'bagging_fraction': 0.8677464790188584, 'max_depth': 10, 'num_leaves': 35, 'learning_rate': 0.04836153350437058, 'n_estimators': 284, 'min_child_samples': 45}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9942568208273629, subsample=0 will be ignored. Current value: bagging_fraction=0.9942568208273629
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9942568208273629, subsample=0 will be ignored. Current value: bagging_fraction=0.9942568208273629
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.979688529929908, subsample=0 will be ignored. Current value: bagging_fraction=0.979688529929908
# [I 2024-12-22 23:13:31,513] Trial 18 finished with value: 0.927165871269355 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.979688529929908, 'max_depth': 10, 'num_leaves': 55, 'learning_rate': 0.018777264445275943, 'n_estimators': 192, 'min_child_samples': 37}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8007042567295104, subsample=0 will be ignored. Current value: bagging_fraction=0.8007042567295104
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8007042567295104, subsample=0 will be ignored. Current value: bagging_fraction=0.8007042567295104
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9081859220598623, subsample=0 will be ignored. Current value: bagging_fraction=0.9081859220598623
# [I 2024-12-22 23:13:43,055] Trial 19 finished with value: 0.9293465290266141 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9081859220598623, 'max_depth': 16, 'num_leaves': 52, 'learning_rate': 0.01453665214933078, 'n_estimators': 226, 'min_child_samples': 30}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8025539035736805, subsample=0 will be ignored. Current value: bagging_fraction=0.8025539035736805
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8025539035736805, subsample=0 will be ignored. Current value: bagging_fraction=0.8025539035736805
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9942568208273629, subsample=0 will be ignored. Current value: bagging_fraction=0.9942568208273629
# [I 2024-12-22 23:14:15,081] Trial 30 finished with value: 0.9277457570162984 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9942568208273629, 'max_depth': 16, 'num_leaves': 63, 'learning_rate': 0.02970286047897064, 'n_estimators': 157, 'min_child_samples': 27}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8025965074999989, subsample=0 will be ignored. Current value: bagging_fraction=0.8025965074999989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8025965074999989, subsample=0 will be ignored. Current value: bagging_fraction=0.8025965074999989
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8007042567295104, subsample=0 will be ignored. Current value: bagging_fraction=0.8007042567295104
# [I 2024-12-22 23:14:22,365] Trial 31 finished with value: 0.9310139499837569 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8007042567295104, 'max_depth': 16, 'num_leaves': 62, 'learning_rate': 0.029364436457019832, 'n_estimators': 159, 'min_child_samples': 28}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8033400464765215, subsample=0 will be ignored. Current value: bagging_fraction=0.8033400464765215
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8033400464765215, subsample=0 will be ignored. Current value: bagging_fraction=0.8033400464765215
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9230248190389526, subsample=0 will be ignored. Current value: bagging_fraction=0.9230248190389526
# [I 2024-12-22 23:14:24,221] Trial 21 finished with value: 0.9304967222287408 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9230248190389526, 'max_depth': 16, 'num_leaves': 63, 'learning_rate': 0.09488817392940319, 'n_estimators': 270, 'min_child_samples': 10}. Best is trial 0 with value: 0.9319993167485211.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8026786192176846, subsample=0 will be ignored. Current value: bagging_fraction=0.8026786192176846
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8026786192176846, subsample=0 will be ignored. Current value: bagging_fraction=0.8026786192176846
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8005906092418401, subsample=0 will be ignored. Current value: bagging_fraction=0.8005906092418401
# [I 2024-12-22 23:14:37,867] Trial 22 finished with value: 0.9327571990839961 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8005906092418401, 'max_depth': 15, 'num_leaves': 63, 'learning_rate': 0.09789507518529475, 'n_estimators': 298, 'min_child_samples': 12}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8223756751745528, subsample=0 will be ignored. Current value: bagging_fraction=0.8223756751745528
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8223756751745528, subsample=0 will be ignored. Current value: bagging_fraction=0.8223756751745528
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8253692627628477, subsample=0 will be ignored. Current value: bagging_fraction=0.8253692627628477
# [I 2024-12-22 23:14:37,931] Trial 23 finished with value: 0.9325696242037046 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8253692627628477, 'max_depth': 16, 'num_leaves': 62, 'learning_rate': 0.09375770544021991, 'n_estimators': 299, 'min_child_samples': 11}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8336231328231763, subsample=0 will be ignored. Current value: bagging_fraction=0.8336231328231763
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8336231328231763, subsample=0 will be ignored. Current value: bagging_fraction=0.8336231328231763
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9977736307230748, subsample=0 will be ignored. Current value: bagging_fraction=0.9977736307230748
# [I 2024-12-22 23:14:41,000] Trial 24 finished with value: 0.9270078294553223 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9977736307230748, 'max_depth': 16, 'num_leaves': 63, 'learning_rate': 0.029781736008853782, 'n_estimators': 300, 'min_child_samples': 13}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8450385442688746, subsample=0 will be ignored. Current value: bagging_fraction=0.8450385442688746
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8450385442688746, subsample=0 will be ignored. Current value: bagging_fraction=0.8450385442688746
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.999325472913606, subsample=0 will be ignored. Current value: bagging_fraction=0.999325472913606
# [I 2024-12-22 23:14:42,644] Trial 26 finished with value: 0.926003705202529 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.999325472913606, 'max_depth': 16, 'num_leaves': 62, 'learning_rate': 0.030390690880880172, 'n_estimators': 284, 'min_child_samples': 27}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8326473228904666, subsample=0 will be ignored. Current value: bagging_fraction=0.8326473228904666
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8326473228904666, subsample=0 will be ignored. Current value: bagging_fraction=0.8326473228904666
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8025539035736805, subsample=0 will be ignored. Current value: bagging_fraction=0.8025539035736805
# [I 2024-12-22 23:14:43,744] Trial 32 finished with value: 0.9327045184793185 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8025539035736805, 'max_depth': 15, 'num_leaves': 61, 'learning_rate': 0.02736135998045215, 'n_estimators': 155, 'min_child_samples': 10}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8357633548795863, subsample=0 will be ignored. Current value: bagging_fraction=0.8357633548795863
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8357633548795863, subsample=0 will be ignored. Current value: bagging_fraction=0.8357633548795863
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8293397998534991, subsample=0 will be ignored. Current value: bagging_fraction=0.8293397998534991
# [I 2024-12-22 23:14:46,494] Trial 25 finished with value: 0.932000913130481 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8293397998534991, 'max_depth': 16, 'num_leaves': 63, 'learning_rate': 0.033742876784819985, 'n_estimators': 300, 'min_child_samples': 11}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8448111169252294, subsample=0 will be ignored. Current value: bagging_fraction=0.8448111169252294
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8448111169252294, subsample=0 will be ignored. Current value: bagging_fraction=0.8448111169252294
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8080426111186784, subsample=0 will be ignored. Current value: bagging_fraction=0.8080426111186784
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.9880057462660123, subsample=0 will be ignored. Current value: bagging_fraction=0.9880057462660123
# [I 2024-12-22 23:14:48,212] Trial 29 finished with value: 0.9315271867838729 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8080426111186784, 'max_depth': 16, 'num_leaves': 63, 'learning_rate': 0.02735772747202092, 'n_estimators': 275, 'min_child_samples': 27}. Best is trial 22 with value: 0.9327571990839961.
# [I 2024-12-22 23:14:48,216] Trial 27 finished with value: 0.9281217049678608 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.9880057462660123, 'max_depth': 16, 'num_leaves': 63, 'learning_rate': 0.030538676265739945, 'n_estimators': 282, 'min_child_samples': 27}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8323934213101093, subsample=0 will be ignored. Current value: bagging_fraction=0.8323934213101093
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8307716192564369, subsample=0 will be ignored. Current value: bagging_fraction=0.8307716192564369
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8323934213101093, subsample=0 will be ignored. Current value: bagging_fraction=0.8323934213101093
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8307716192564369, subsample=0 will be ignored. Current value: bagging_fraction=0.8307716192564369
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8291261289778744, subsample=0 will be ignored. Current value: bagging_fraction=0.8291261289778744
# [I 2024-12-22 23:14:56,251] Trial 28 finished with value: 0.9307134310798006 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8291261289778744, 'max_depth': 16, 'num_leaves': 63, 'learning_rate': 0.027566241088466982, 'n_estimators': 300, 'min_child_samples': 27}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8355990105850324, subsample=0 will be ignored. Current value: bagging_fraction=0.8355990105850324
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8355990105850324, subsample=0 will be ignored. Current value: bagging_fraction=0.8355990105850324
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8026786192176846, subsample=0 will be ignored. Current value: bagging_fraction=0.8026786192176846
# [I 2024-12-22 23:15:16,989] Trial 35 finished with value: 0.9321441884113844 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8026786192176846, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.02829702349047098, 'n_estimators': 162, 'min_child_samples': 15}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8422375918606869, subsample=0 will be ignored. Current value: bagging_fraction=0.8422375918606869
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8422375918606869, subsample=0 will be ignored. Current value: bagging_fraction=0.8422375918606869
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8033400464765215, subsample=0 will be ignored. Current value: bagging_fraction=0.8033400464765215
# [I 2024-12-22 23:15:17,051] Trial 34 finished with value: 0.932479428622969 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8033400464765215, 'max_depth': 15, 'num_leaves': 62, 'learning_rate': 0.030003872072935603, 'n_estimators': 160, 'min_child_samples': 14}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8496835683758494, subsample=0 will be ignored. Current value: bagging_fraction=0.8496835683758494
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8496835683758494, subsample=0 will be ignored. Current value: bagging_fraction=0.8496835683758494
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8025965074999989, subsample=0 will be ignored. Current value: bagging_fraction=0.8025965074999989
# [I 2024-12-22 23:15:41,705] Trial 33 finished with value: 0.9325444811878358 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8025965074999989, 'max_depth': 14, 'num_leaves': 59, 'learning_rate': 0.02780641070185086, 'n_estimators': 269, 'min_child_samples': 10}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8448620713809569, subsample=0 will be ignored. Current value: bagging_fraction=0.8448620713809569
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8448620713809569, subsample=0 will be ignored. Current value: bagging_fraction=0.8448620713809569
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8496835683758494, subsample=0 will be ignored. Current value: bagging_fraction=0.8496835683758494
# [I 2024-12-22 23:15:59,501] Trial 46 finished with value: 0.9311979330046383 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8496835683758494, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.08879986899289485, 'n_estimators': 134, 'min_child_samples': 18}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8174877997015381, subsample=0 will be ignored. Current value: bagging_fraction=0.8174877997015381
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8174877997015381, subsample=0 will be ignored. Current value: bagging_fraction=0.8174877997015381
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8326473228904666, subsample=0 will be ignored. Current value: bagging_fraction=0.8326473228904666
# [I 2024-12-22 23:16:05,996] Trial 39 finished with value: 0.9314581432641061 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8326473228904666, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.0854415047573498, 'n_estimators': 260, 'min_child_samples': 18}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8193269875692701, subsample=0 will be ignored. Current value: bagging_fraction=0.8193269875692701
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8193269875692701, subsample=0 will be ignored. Current value: bagging_fraction=0.8193269875692701
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8450385442688746, subsample=0 will be ignored. Current value: bagging_fraction=0.8450385442688746
# [I 2024-12-22 23:16:06,811] Trial 38 finished with value: 0.9311628126015199 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8450385442688746, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.08623191056355868, 'n_estimators': 268, 'min_child_samples': 18}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8357633548795863, subsample=0 will be ignored. Current value: bagging_fraction=0.8357633548795863
# [I 2024-12-22 23:16:09,350] Trial 40 finished with value: 0.9312111031558077 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8357633548795863, 'max_depth': 15, 'num_leaves': 58, 'learning_rate': 0.08870047950577381, 'n_estimators': 274, 'min_child_samples': 17}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8422375918606869, subsample=0 will be ignored. Current value: bagging_fraction=0.8422375918606869
# [I 2024-12-22 23:16:09,447] Trial 45 finished with value: 0.9315196039695633 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8422375918606869, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.08871089606211824, 'n_estimators': 168, 'min_child_samples': 16}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8448111169252294, subsample=0 will be ignored. Current value: bagging_fraction=0.8448111169252294
# [I 2024-12-22 23:16:09,636] Trial 41 finished with value: 0.9312043185324781 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8448111169252294, 'max_depth': 15, 'num_leaves': 58, 'learning_rate': 0.08451680994713177, 'n_estimators': 267, 'min_child_samples': 17}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8223756751745528, subsample=0 will be ignored. Current value: bagging_fraction=0.8223756751745528
# [I 2024-12-22 23:16:09,986] Trial 36 finished with value: 0.9322998356524772 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8223756751745528, 'max_depth': 14, 'num_leaves': 59, 'learning_rate': 0.0826383986379724, 'n_estimators': 292, 'min_child_samples': 15}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8336231328231763, subsample=0 will be ignored. Current value: bagging_fraction=0.8336231328231763
# [I 2024-12-22 23:16:10,162] Trial 37 finished with value: 0.9315838583434506 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8336231328231763, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.08842378402494631, 'n_estimators': 294, 'min_child_samples': 15}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8355990105850324, subsample=0 will be ignored. Current value: bagging_fraction=0.8355990105850324
# [I 2024-12-22 23:16:11,436] Trial 44 finished with value: 0.9311197102886019 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8355990105850324, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.08790645117874565, 'n_estimators': 263, 'min_child_samples': 18}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8307716192564369, subsample=0 will be ignored. Current value: bagging_fraction=0.8307716192564369
# [I 2024-12-22 23:16:11,929] Trial 43 finished with value: 0.9314780980386053 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8307716192564369, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.0882663832954158, 'n_estimators': 299, 'min_child_samples': 17}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8323934213101093, subsample=0 will be ignored. Current value: bagging_fraction=0.8323934213101093
# [I 2024-12-22 23:16:11,967] Trial 42 finished with value: 0.9315351686936727 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8323934213101093, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.08571806418787543, 'n_estimators': 300, 'min_child_samples': 17}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8448620713809569, subsample=0 will be ignored. Current value: bagging_fraction=0.8448620713809569
# [I 2024-12-22 23:16:14,514] Trial 47 finished with value: 0.931095764559203 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8448620713809569, 'max_depth': 15, 'num_leaves': 59, 'learning_rate': 0.0904198959714695, 'n_estimators': 262, 'min_child_samples': 19}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8174877997015381, subsample=0 will be ignored. Current value: bagging_fraction=0.8174877997015381
# [I 2024-12-22 23:16:15,271] Trial 48 finished with value: 0.9318588351360476 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8174877997015381, 'max_depth': 14, 'num_leaves': 59, 'learning_rate': 0.08224410677892868, 'n_estimators': 265, 'min_child_samples': 18}. Best is trial 22 with value: 0.9327571990839961.
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8193269875692701, subsample=0 will be ignored. Current value: bagging_fraction=0.8193269875692701
# [I 2024-12-22 23:16:15,383] Trial 49 finished with value: 0.9312242733069771 and parameters: {'bagging_freq': 2, 'bagging_fraction': 0.8193269875692701, 'max_depth': 14, 'num_leaves': 57, 'learning_rate': 0.07893813205886246, 'n_estimators': 265, 'min_child_samples': 21}. Best is trial 22 with value: 0.9327571990839961.

# %%
params = study.best_params

rf_model = LGBMClassifier(**params, verbose=0)

rf_model.fit(X_train, y_train)
y_pred = rf_model.predict_proba(X_test)[:, 1]


roc_auc_score(y_test, y_pred)
# Out:
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8005906092418401, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8005906092418401
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8005906092418401, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8005906092418401
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] bagging_fraction is set=0.8005906092418401, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8005906092418401
# 0.9356419937555404

# %%
optuna.visualization.plot_param_importances(study)
# Out:
# <div>                            <div id="5edd20f9-121d-4fe5-96b0-06cd3be1a541" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5edd20f9-121d-4fe5-96b0-06cd3be1a541")) {                    Plotly.newPlot(                        "5edd20f9-121d-4fe5-96b0-06cd3be1a541",                        [{"cliponaxis":false,"hovertemplate":["bagging_freq (IntDistribution): 0.0033300446629800904\u003cextra\u003e\u003c\u002fextra\u003e","max_depth (IntDistribution): 0.008989239806469906\u003cextra\u003e\u003c\u002fextra\u003e","n_estimators (IntDistribution): 0.020007336872247282\u003cextra\u003e\u003c\u002fextra\u003e","learning_rate (FloatDistribution): 0.06496345895777739\u003cextra\u003e\u003c\u002fextra\u003e","min_child_samples (IntDistribution): 0.08272701855152931\u003cextra\u003e\u003c\u002fextra\u003e","num_leaves (IntDistribution): 0.2637313684344666\u003cextra\u003e\u003c\u002fextra\u003e","bagging_fraction (FloatDistribution): 0.5562515327145295\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value","orientation":"h","text":["\u003c0.01","\u003c0.01","0.02","0.06","0.08","0.26","0.56"],"textposition":"outside","x":[0.0033300446629800904,0.008989239806469906,0.020007336872247282,0.06496345895777739,0.08272701855152931,0.2637313684344666,0.5562515327145295],"y":["bagging_freq","max_depth","n_estimators","learning_rate","min_child_samples","num_leaves","bagging_fraction"],"type":"bar"}],                        {"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Hyperparameter Importance"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46 ...

# %% [markdown]
# Ну качество получше получилось, хотя понтяно что бустинг у меня слабоватый. Да, в целом случайный лес актуален

# %% [markdown]
# ### 3.4. Бустинг и вероятности (0.5 балла)
#
# С качеством мы более-менее разобрались, но что насчет вероятностей? Постройте калибровочную кривую для вашей лучшей модели бустинга. Насколько хорошо бустинг оценивает вероятности?

# %%
def plot_calibration_curve(y_test, preds, name):
    bin_middle_points = []
    bin_real_ratios = []
    n_bins = 10
    for i in range(n_bins):
        l = 1.0 / n_bins * i
        r = 1.0 / n_bins * (i + 1)        
        bin_middle_points.append((l + r) / 2) 
        
        ones = (y_test[(preds >= l) & (preds < r)] == 1)
        
        bin_real_ratios.append(ones.sum() / len(ones))
        
    plt.figure(figsize=(6,6))
    plt.plot(bin_middle_points, bin_real_ratios, label=name)
    plt.plot([0, 1], [0, 1], label='Ideal model')
    plt.ylim([-0.05, 1.05])
    plt.legend()
    plt.grid()

# %%
boosting = Boosting(n_estimators=260, learning_rate=0.28967922722120865, \
                        base_model_params=dict(max_depth=8))

boosting.fit(X_train, y_train)

plot_calibration_curve(y_test, boosting.predict_proba(X_test)[:, 1], 'my')

# %% [markdown]
# Постройте также калибровочную кривую для логистической регрессии, сравните их между собой. Проанализируйте полученные результаты.

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)

plot_calibration_curve(y_test, model.predict_proba(X_test)[:, 1], 'LogisticRegression')

# %% [markdown]
# Понятно, что логрег сильно лучше.

# %% [markdown]
# ## Социализационный бонус. Новогоднее 🎆 (0.5 балла)
#
# Сфотографируйтесь с наряженной новогодней или рождественской ёлкой! Приложите фотографию, опишите свои впечатления, чего вы ждете от нового 2025 года?

# %% [markdown]
# # *𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚*𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚*𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚*𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚*𖣂♱𖠰𖣂↟*𖠰ᨒ↟*𖥧˚
